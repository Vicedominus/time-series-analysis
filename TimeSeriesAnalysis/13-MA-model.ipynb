# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima.model import ARIMA
from datetime import datetime, timedelta
register_matplotlib_converters()

# %%
errors = np.random.normal(0, 1, 400)

# %%
date_index = pd.date_range(start='9/1/2019', end='1/1/2020')

# %%
mu = 50
series = []
for t in range(1,len(date_index)+1):
    series.append(mu + 0.4*errors[t-1] + 0.3*errors[t-2] + errors[t])

# %%
series = pd.Series(series, date_index)
series = series.asfreq(pd.infer_freq(series.index))
series
# Out:
# 2019-09-01    51.537327
# 2019-09-02    50.562453
# 2019-09-03    50.168087
# 2019-09-04    50.776204
# 2019-09-05    49.013415
#                 ...
# 2019-12-28    47.230538
# 2019-12-29    48.217025
# 2019-12-30    49.071623
# 2019-12-31    49.594699
# 2020-01-01    51.864590
# Freq: D, Length: 123, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(series)
plt.axhline(mu, linestyle='--', color='grey')

# %%
def calc_corr(series, lag):
    return pearsonr(series[:-lag], series[lag:])[0]

# %%
acf_vals = acf(series)
num_lags = 10
plt.bar(range(num_lags), acf_vals[:num_lags])
# Out:
# <BarContainer object of 10 artists>

# %%
pacf_vals = pacf(series)
num_lags = 25
plt.bar(range(num_lags), pacf_vals[:num_lags])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 pacf_vals = pacf(series)
#       2 num_lags = 25
# ----> 3 plt.bar(range(num_lags), pacf_vals[:num_lags])
#
# File c:\Users\equipo\miniconda3\envs\development\Lib\site-packages\matplotlib\pyplot.py:2367, in bar(x, height, width, bottom, align, data, **kwargs)
#    2363 @_copy_docstring_and_deprecators(Axes.bar)
#    2364 def bar(
#    2365         x, height, width=0.8, bottom=None, *, align='center',
#    2366         data=None, **kwargs):
# -> 2367     return gca().bar(
#    2368         x, height, width=width, bottom=bottom, align=align,
#    2369         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\equipo\miniconda3\envs\development\Lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\Users\equipo\miniconda3\envs\development\Lib\site-packages\matplotlib\axes\_axes.py:2391, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2388     if yerr is not None:
#    2389         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2391 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2392     # Make args iterable too.
#    2393     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2395 # Now that units have been converted, set the tick locations.
#    2396 if orientation == 'vertical':
#
# File <__array_function__ internals>:200, in broadcast_arrays(*args, **kwargs)
#
# File c:\Users\equipo\miniconda3\envs\development\Lib\site-packages\numpy\lib\stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File c:\Users\equipo\miniconda3\envs\development\Lib\site-packages\numpy\lib\stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (25,) and arg 1 with shape (21,).

# %%
train_end = datetime(2019,12,30)
test_end = datetime(2020,1,1)

train_data = series[:train_end]
test_data = series[train_end + timedelta(days=1):test_end]

# %%
#create the model
model = ARIMA(train_data, order=(0,0,2))

# %%
#fit the model
model_fit = model.fit()

# %%
#summary of the model
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  121
# Model:                 ARIMA(0, 0, 2)   Log Likelihood                -164.167
# Date:                Sun, 05 Feb 2023   AIC                            336.334
# Time:                        06:47:53   BIC                            347.517
# Sample:                    09-01-2019   HQIC                           340.876
#                          - 12-30-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         49.9120      0.157    317.564      0.000      49.604      50.220
# ma.L1          0.4189      0.082      5.081      0.000       0.257       0.581
# ma.L2          0.4377      0.104      4.223      0.000       0.235       0.641
# sigma2         0.8793      0.111      7.888      0.000       0.661       1.098
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.32
# Prob(Q):                              0.85   Prob(JB):                         0.85
# Heteroskedasticity (H):               0.73   Skew:                             0.12
# Prob(H) (two-sided):                  0.33   Kurtosis:                         3.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#get prediction start and end dates
pred_start_date = test_data.index[0]
pred_end_date = test_data.index[-1]

# %%
#get the predictions and residuals
predictions = model_fit.predict(start=pred_start_date, end=pred_end_date)

# %%
residuals = test_data - predictions

# %%
plt.figure(figsize=(10,4))

plt.plot(series[-14:])
plt.plot(predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(residuals/test_data)),4))
# Out:
# Mean Absolute Percent Error: 0.0216

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(residuals**2)))
# Out:
# Root Mean Squared Error: 1.3620189294220928
